# %%
# !pip install yfinance --upgrade --no-cache-dir
# !pip install fix_yahoo_finance --upgrade --no-cache-dir
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.17-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.9.1 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance) (4.9.1)
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.7-cp310-cp310-macosx_11_0_arm64.whl (35 kB)
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=3.3.2 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance) (38.0.4)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance) (4.12.0)
# Requirement already satisfied: pytz>=2022.5 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance) (2022.7)
# Requirement already satisfied: numpy>=1.16.5 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance) (1.23.5)
# Collecting pandas>=1.3.0
#   Downloading pandas-2.0.0-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 92.1 MB/s eta 0:00:00 0:00:01
# Collecting appdirs>=1.4.4
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests>=2.26 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: cffi>=1.12 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: webencodings in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 157.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: pycparser in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Installing collected packages: multitasking, appdirs, tzdata, html5lib, frozendict, pandas, yfinance
# Successfully installed appdirs-1.4.4 frozendict-2.3.7 html5lib-1.1 multitasking-0.0.11 pandas-2.0.0 tzdata-2023.3 yfinance-0.2.17
# Collecting fix_yahoo_finance
#   Downloading fix-yahoo-finance-0.1.37.tar.gz (6.3 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: yfinance in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from fix_yahoo_finance) (0.2.17)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance->fix_yahoo_finance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance->fix_yahoo_finance) (4.9.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance->fix_yahoo_finance) (1.23.5)
# Requirement already satisfied: cryptography>=3.3.2 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance->fix_yahoo_finance) (38.0.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance->fix_yahoo_finance) (4.12.0)
# Requirement already satisfied: requests>=2.26 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance->fix_yahoo_finance) (2.28.1)
# Requirement already satisfied: html5lib>=1.1 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance->fix_yahoo_finance) (1.1)
# Requirement already satisfied: pytz>=2022.5 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance->fix_yahoo_finance) (2022.7)
# Requirement already satisfied: pandas>=1.3.0 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance->fix_yahoo_finance) (2.0.0)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance->fix_yahoo_finance) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from yfinance->fix_yahoo_finance) (2.3.7)
# Requirement already satisfied: soupsieve>1.2 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance->fix_yahoo_finance) (2.4)
# Requirement already satisfied: cffi>=1.12 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from cryptography>=3.3.2->yfinance->fix_yahoo_finance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from html5lib>=1.1->yfinance->fix_yahoo_finance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from html5lib>=1.1->yfinance->fix_yahoo_finance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance->fix_yahoo_finance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance->fix_yahoo_finance) (2023.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance->fix_yahoo_finance) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance->fix_yahoo_finance) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance->fix_yahoo_finance) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance->fix_yahoo_finance) (2.0.4)
# Requirement already satisfied: pycparser in /Users/macbookair/miniconda3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance->fix_yahoo_finance) (2.21)
# Building wheels for collected packages: fix_yahoo_finance
#   Building wheel for fix_yahoo_finance (setup.py) ... done
#   Created wheel for fix_yahoo_finance: filename=fix_yahoo_finance-0.1.37-py3-none-any.whl size=7073 sha256=223adb401dfe9e85eacea5cae457d4d9b0d7fc6acc6b7294b60d8596bfd3e914
#   Stored in directory: /private/var/folders/34/wft3ncqd4ks3489rf30mb_x80000gn/T/pip-ephem-wheel-cache-_gkbqvqx/wheels/f9/21/75/611919983c9961f56d944464dacd1d90886daa5e0daa9bd951
# Successfully built fix_yahoo_finance
# Installing collected packages: fix_yahoo_finance
# Successfully installed fix_yahoo_finance-0.1.37

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_datareader import data as pdr
#import fix_yahoo_finance as yf
import yfinance as yf
yf.pdr_override()
df_full = pdr.get_data_yahoo("BTCXUSD", start="2018-01-01").reset_index()
df_full.head()
sns.set()

# %%
from collections import deque
import random
from tensorflow.python.framework import ops
# %tensorflow_version 2.x

df= df_full.copy()
name = 'Q-learning agent'

class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        ops.reset_default_graph()
        self.sess=tf.compat.v1.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
import tensorflow.compat.v2 as tf
#tf.disable_v2_behavior()

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('S&P 500 | Total gains in USD: %f, Total Investment: %f%%'%(total_gains, invest))
plt.legend()
plt.show()
